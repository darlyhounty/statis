# %%
from statsmodels.tsa.statespace.varmax import VARMAX
from random import random
# contrived dataset with dependency
data = list()
for i in range(100):
    v1 = random()
    v2 = v1 + random()
    row = [v1, v2]
    data.append(row)

# %%
# fit model
model2_2 = VARMAX(data, order=(2, 2))
model2_3 = VARMAX(data, order=(2, 3))
model2_4 = VARMAX(data, order=(2, 4))
model3_2 = VARMAX(data, order=(3, 2))
model3_3 = VARMAX(data, order=(3, 3))
model3_4 = VARMAX(data, order=(3, 4))
model4_2 = VARMAX(data, order=(4, 2))
model4_3 = VARMAX(data, order=(4, 3))
model4_4 = VARMAX(data, order=(4, 4))
model_fit2_2 = model2_2.fit(disp=False)
model_fit2_3 = model2_3.fit(disp=False)
model_fit2_4 = model2_4.fit(disp=False)
model_fit3_2 = model3_2.fit(disp=False)
model_fit3_3 = model3_3.fit(disp=False)
model_fit3_4 = model3_4.fit(disp=False)
model_fit4_2 = model4_2.fit(disp=False)
model_fit4_3 = model4_3.fit(disp=False)
model_fit4_4 = model4_4.fit(disp=False)
# Out:
# E:\anaconda\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# E:\anaconda\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# E:\anaconda\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# E:\anaconda\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
# ...

# %%
yhatprint(res.summary())
# Out:
# E:\anaconda\lib\site-packages\statsmodels\tsa\statespace\varmax.py:161: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# E:\anaconda\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
print(model_fit4_4.summary())
# Out:
#                            Statespace Model Results
# ...
# Dep. Variable:           ['y1', 'y2']   No. Observations:                  100
# Model:                     VARMA(4,4)   Log Likelihood                  -1.483
#                           + intercept   AIC                             76.965
# Date:                Sun, 16 Jan 2022   BIC                            173.357
# Time:                        20:38:26   HQIC                           115.977
# Sample:                             0
#                                 - 100
# Covariance Type:                  opg
# ...
# Ljung-Box (L1) (Q):             0.02, 0.10   Jarque-Bera (JB):           2.41, 1.79
# Prob(Q):                        0.88, 0.76   Prob(JB):                   0.30, 0.41
# Heteroskedasticity (H):         0.81, 0.85   Skew:                      -0.16, 0.07
# Prob(H) (two-sided):            0.54, 0.65   Kurtosis:                   2.31, 2.36
#                            Results for equation y1
# ...

# %%
plt.plot(data)

# %%
print(model_fit.impulse_responses(8))
# Out:
# [[ 1.00000000e+00  0.00000000e+00]
#  [-2.50396964e-02 -1.37162914e-01]
#  [-5.90795815e-02 -1.52513899e-01]
#  [-4.55500590e-02 -1.85800896e-02]
#  [ 2.28123638e-03 -9.43839947e-02]
#  [ 1.29378666e-02  7.18026639e-03]
#  [-1.20825139e-02 -5.92047071e-02]
#  [-2.11392902e-02  3.42051201e-02]
#  [-3.45781300e-04 -4.75087273e-02]]
